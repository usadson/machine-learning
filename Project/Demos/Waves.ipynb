# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(0, 8*np.pi, 0.01)   # start,stop,step
y = np.sin(x)

plt.plot(x,y)
plt.xticks([])
plt.yticks([])
plt.axhline(y=0, color='r', linestyle='-')
plt.ylim(-2, 2)
plt.show()
