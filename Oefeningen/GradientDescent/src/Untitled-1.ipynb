# %%
for i in range(1, 1000):
    print("i:", i, " = ", i / 0.001)
# Out:
# i: 1  =  1000.0
# i: 2  =  2000.0
# i: 3  =  3000.0
# i: 4  =  4000.0
# i: 5  =  5000.0
# i: 6  =  6000.0
# i: 7  =  7000.0
# i: 8  =  8000.0
# i: 9  =  9000.0
# i: 10  =  10000.0
# i: 11  =  11000.0
# i: 12  =  12000.0
# i: 13  =  13000.0
# i: 14  =  14000.0
# i: 15  =  15000.0
# i: 16  =  16000.0
# i: 17  =  17000.0
# i: 18  =  18000.0
# i: 19  =  19000.0
# i: 20  =  20000.0
# i: 21  =  21000.0
# i: 22  =  22000.0
# i: 23  =  23000.0
# i: 24  =  24000.0
# i: 25  =  25000.0
# i: 26  =  26000.0
# i: 27  =  27000.0
# i: 28  =  28000.0
# i: 29  =  29000.0
# i: 30  =  30000.0
# i: 31  =  31000.0
# i: 32  =  32000.0
# i: 33  =  33000.0
# i: 34  =  34000.0
# i: 35  =  35000.0
# i: 36  =  36000.0
# i: 37  =  37000.0
# i: 38  =  38000.0
# i: 39  =  39000.0
# i: 40  =  40000.0
# i: 41  =  41000.0
# i: 42  =  42000.0
# i: 43  =  43000.0
# i: 44  =  44000.0
# i: 45  =  45000.0
# i: 46  =  46000.0
# i: 47  =  47000.0
# i: 48  =  48000.0
# i: 49  =  49000.0
# i: 50  =  50000.0
# ...
